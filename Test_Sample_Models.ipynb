# %%
import sample_models as SM
# Out:
# Using TensorFlow backend.

# %%
SM.simple_rnn_model(161);
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# rnn1 (SimpleRNN)             (None, None, 200)         72400
# _________________________________________________________________
# softmax (Activation)         (None, None, 200)         0
# ...
# Total params: 72,400
# Trainable params: 72,400
# Non-trainable params: 0
# _________________________________________________________________

# %%
SM.rnn_model(161, 100, 'relu');
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# rnn1 (CuDNNLSTM)             (None, None, 100)         105200
# _________________________________________________________________
# TDD_BN (BatchNormalization)  (None, None, 100)         400
# _________________________________________________________________
# relu (Activation)            (None, None, 100)         0
# _________________________________________________________________
# TDD_DO (Dropout)             (None, None, 100)         0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, None, 29)          2929
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# ...
# Total params: 108,529
# ...

# %%
SM.cnn_rnn_model(input_dim=161, filters=100, kernel_size=11, conv_stride=2,
                  conv_border_mode="valid", units=200);
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# conv1d1 (Conv1D)             (None, None, 100)         177200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, None, 100)         0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, None, 100)         400
# _________________________________________________________________
# rnn1 (CuDNNLSTM)             (None, None, 200)         241600
# _________________________________________________________________
# TDD_BN (BatchNormalization)  (None, None, 200)         800
# _________________________________________________________________
# relu (Activation)            (None, None, 200)         0
# ...

# %%
SM.deep_rnn_model(input_dim=161, units=200, recur_layers=2);
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# rnn1 (CuDNNLSTM)             (None, None, 200)         290400
# _________________________________________________________________
# R_BN_0 (BatchNormalization)  (None, None, 200)         800
# _________________________________________________________________
# reluR0 (Activation)          (None, None, 200)         0
# _________________________________________________________________
# R_DO_0 (Dropout)             (None, None, 200)         0
# _________________________________________________________________
# rnn2 (CuDNNLSTM)             (None, None, 200)         321600
# _________________________________________________________________
# TDD_BN (BatchNormalization)  (None, None, 200)         800
# ...

# %%
SM.bidirectional_rnn_model(input_dim=161, units=200);
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# the_input (InputLayer)       (None, None, 161)         0
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, None, 400)         580800
# _________________________________________________________________
# TDD_BN (BatchNormalization)  (None, None, 400)         1600
# _________________________________________________________________
# relu (Activation)            (None, None, 400)         0
# _________________________________________________________________
# TDD_DO (Dropout)             (None, None, 400)         0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, None, 29)          11629
# _________________________________________________________________
# softmax (Activation)         (None, None, 29)          0
# ...
# Total params: 594,029
# ...

# %%
SM.final_model();
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# the_input (InputLayer)          (None, None, 26)     0
# __________________________________________________________________________________________________
# conv1d1 (Conv1D)                (None, None, 200)    15800       the_input[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, None, 200)    0           conv1d1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, 200)    800         dropout_3[0][0]
# __________________________________________________________________________________________________
# conv1d2 (Conv1D)                (None, None, 200)    120200      batch_normalization_3[0][0]
# ...
